# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_and_count_predicates, parse_and_count_classes, parse_and_count_domain_suffixes

# %%
answer_filenames = []
for i in range(118):
    answer_filenames.append(rf"E:\schema_org_datasets\Answer\Answer_part_{i}.gz")

# %%
parse_and_count_classes(answer_filenames, "Answer", "2024")
# Out:
# <http://schema.org/Answer>: 10470981
# <http://schema.org/Question>: 10361247
# <http://schema.org/FAQPage>: 8355791
# <http://schema.org/ListItem>: 6815397
# <http://schema.org/BreadcrumbList>: 6704861
# <http://schema.org/Organization>: 4517193
# <https://schema.org/Answer>: 3903734
# <https://schema.org/Question>: 3877915
# <http://schema.org/Person>: 3676011
# <http://schema.org/ImageObject>: 3665443

# %%
parse_and_count_predicates(answer_filenames, "Answer", "2024")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 59240980 100.0%
# <http://schema.org/url> 7715197 13.02%
# <http://schema.org/upvoteCount> 7229612 12.2%
# <http://schema.org/author> 7056452 11.91%
# <http://schema.org/dateCreated> 5706923 9.63%
# <http://schema.org/text> 2435975 4.11%
# <http://schema.org/inLanguage> 1790894 3.02%
# <http://schema.org/comment> 658525 1.11%
# <http://schema.org/encodingFormat> 644119 1.09%
# <http://schema.org/position> 634753 1.07%

# %%
parse_and_count_domain_suffixes(answer_filenames, "Answer", "2024")
# Out:
# Top 10 sufiksi 2024:
# com 34150580 57.65%
# net 2066702 3.49%
# de 1989982 3.36%
# ru 1440079 2.43%
# fr 1339892 2.26%
# co.uk 1233326 2.08%
# org 1197680 2.02%
# in 1173519 1.98%
# nl 1145618 1.93%
# com.au 759997 1.28%
