# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_and_count_predicates, parse_and_count_classes, parse_and_count_domain_suffixes, parse_and_count_predicates_all_classes

# %%
music_album_filenames = []
for i in range(5):
    music_album_filenames.append(rf"E:\schema_org_datasets\MusicAlbum\MusicAlbum_part_{i}.gz")

# %%
parse_and_count_classes(music_album_filenames, "MusicAlbum", "2024")
# Out:
# <http://schema.org/MusicAlbum>: 523917
# <http://schema.org/MusicGroup>: 437178
# <http://schema.org/Offer>: 297639
# <http://schema.org/Organization>: 275026
# <http://schema.org/MusicRecording>: 231040
# <http://schema.org/EntryPoint>: 122917
# <http://schema.org/ListenAction>: 113117
# <http://schema.org/ListItem>: 102637
# <http://schema.org/BreadcrumbList>: 92256
# <http://schema.org/WebSite>: 86072

# %%
parse_and_count_predicates(music_album_filenames, "MusicAlbum", "2024")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 1936996 100.0%
# <http://schema.org/url> 1611554 83.2%
# <http://schema.org/image> 1543534 79.69%
# <http://schema.org/byArtist> 738904 38.15%
# <http://schema.org/datePublished> 300327 15.5%
# <http://schema.org/name> 249876 12.9%
# <http://schema.org/albumProductionType> 212937 10.99%
# <http://schema.org/offers> 204729 10.57%
# <http://schema.org/albumReleaseType> 182902 9.44%
# <http://schema.org/publisher> 177005 9.14%

# %%
parse_and_count_domain_suffixes(music_album_filenames, "MusicAlbum", "2024")
# Out:
# Top 10 sufiksi 2024:
# com 1491161 76.98%
# fm 183264 9.46%
# net 80639 4.16%
# de 75468 3.9%
# jp 17824 0.92%
# fr 14511 0.75%
# fi 10137 0.52%
# co 6016 0.31%
# nl 5449 0.28%
# org 4004 0.21%

# %%
parse_and_count_predicates_all_classes(music_album_filenames, "MusicAlbum", "2024")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 2193334 100.0%
# <http://schema.org/url> 1611553 73.48%
# <http://schema.org/image> 1543528 70.37%
# <http://schema.org/byArtist> 738904 33.69%
# <http://schema.org/datePublished> 300326 13.69%
# <http://schema.org/name> 249874 11.39%
# <http://schema.org/albumProductionType> 212937 9.71%
# <http://schema.org/offers> 204729 9.33%
# <https://schema.org/url> 188097 8.58%
# <http://schema.org/albumReleaseType> 182902 8.34%
#
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 1411922 100.0%
# <http://schema.org/url> 897880 63.59%
# <http://schema.org/name> 258738 18.33%
# <https://schema.org/url> 128979 9.13%
# <http://schema.org/image> 61637 4.37%
# <https://schema.org/name> 48293 3.42%
# <http://www.schema.org/url> 47716 3.38%
# <http://schema.org/potentialAction> 29062 2.06%
# <http://schema.org/album> 27974 1.98%
# <http://schema.org/track> 18498 1.31%
#
# Top 10 predikāti 2024:
# ...
