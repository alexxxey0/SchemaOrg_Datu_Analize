# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_gz_files, top_10_predicates

# %%
# Iegūt četriniekus klasei Dataset 2024. gada datu kopā

dataset_filenames = []
for i in range(1, 6):
    dataset_filenames.append(f"../dataset_2024_p{i}.gz")

dataset_quads = {}
dataset_quads["2024"] = parse_gz_files(dataset_filenames, "Dataset")

# %%
top_10_predicates(dataset_quads)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 predicate_counter = Counter()
#       6 for s, p, o, graph in quads:
# ----> 7     predicate_counter[p] += 1
#       9 top_predicates = predicate_counter.most_common(10)
#      11 print(f"\nTop 10 predikāti {year}:")
#
# KeyboardInterrupt:
