# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_gz_files, top_10_predicates, parse_and_count_classes

# %%
# Iegūt četriniekus klasei Dataset 2024. gada datu kopā

dataset_filenames = []
for i in range(1, 6):
    dataset_filenames.append(f"../dataset_2024_p{i}.gz")

dataset_quads = {}
dataset_quads["2024"] = parse_gz_files(dataset_filenames, "Dataset")

# %%
top_10_predicates(dataset_quads, "Dataset")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 1480364 100.0%
# <http://schema.org/name> 636704 43.01%
# <http://schema.org/creator> 421027 28.44%
# <http://schema.org/url> 386383 26.1%
# <http://schema.org/license> 323953 21.88%
# <http://schema.org/distribution> 248520 16.79%
# <http://schema.org/includedInDataCatalog> 210987 14.25%
# <http://schema.org/spatialCoverage> 171630 11.59%
# <http://schema.org/temporalCoverage> 158497 10.71%
# <http://www.w3.org/1999/xhtml/microdata#item> 138227 9.34%

# %%
dataset_filenames = []
for i in range(1, 6):
    dataset_filenames.append(f"../dataset_2024_p{i}.gz")

parse_and_count_classes(dataset_filenames, "Dataset", "2024")
# Out:
# <http://schema.org/Dataset>: 677460
# <http://schema.org/Organization>: 449662
# <http://schema.org/DataDownload>: 303009
# <http://schema.org/DataCatalog>: 231683
# <http://schema.org/ContactPoint>: 141669
# <http://schema.org/PostalAddress>: 137736
# <http://schema.org/Person>: 125288
# <http://schema.org/CreativeWork>: 113098
# <http://schema.org/Place>: 100115
# <http://schema.org/WebPage>: 93233
