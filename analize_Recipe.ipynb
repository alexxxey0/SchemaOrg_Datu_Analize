# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_and_count_predicates, parse_and_count_classes

# %%
recipe_filenames = []
for i in range(21):
    recipe_filenames.append(rf"E:\schema_org_datasets\Recipe\Recipe_part_{i}.gz")

# %%
parse_and_count_classes(recipe_filenames, "Recipe", "2024")
# Out:
# <http://schema.org/Recipe>: 2586159
# <http://schema.org/Person>: 1713850
# <http://schema.org/HowToStep>: 1390644
# <http://schema.org/ListItem>: 1380946
# <http://schema.org/BreadcrumbList>: 1352006
# <http://schema.org/ImageObject>: 1349001
# <http://schema.org/Organization>: 1314474
# <http://schema.org/AggregateRating>: 1213185
# <http://schema.org/WebPage>: 1137702
# <http://schema.org/WebSite>: 1066296

# %%
parse_and_count_predicates(recipe_filenames, "Recipe", "2024")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 2874812 100.0%
# <http://schema.org/image> 2692018 93.64%
# <http://schema.org/author> 2136441 74.32%
# <http://schema.org/datePublished> 1686970 58.68%
# <http://schema.org/totalTime> 1650804 57.42%
# <http://schema.org/prepTime> 1597685 55.58%
# <http://schema.org/cookTime> 1497305 52.08%
# <http://schema.org/recipeInstructions> 1431101 49.78%
# <http://schema.org/recipeYield> 1398641 48.65%
# <http://schema.org/aggregateRating> 1229242 42.76%
