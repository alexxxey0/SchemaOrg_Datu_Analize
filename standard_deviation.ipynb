# %%
from helpers import parse_mean_std_predicates

schema_org_classes = [
    "Answer",
    "Book",
    "Dataset",
    "Hospital",
    "Movie",
    "MusicAlbum",
    "QAPage",
    "Recipe",
    "School",
    "ShoppingCenter"
]
    

filenames = {}

filenames['Answer'] = []
for i in range(118):
    filenames['Answer'].append(rf"E:\schema_org_datasets\Answer\Answer_part_{i}.gz")
    
filenames['Book'] = []
for i in range(19):
    filenames['Book'].append(rf"E:\schema_org_datasets\Book\Book_part_{i}.gz")
    
filenames['Dataset'] = []
for i in range(1, 6):
    filenames['Dataset'].append(f"../dataset_2024_p{i}.gz")
    
filenames["Hospital"] = ["../hospital_2024_p1.gz", "../hospital_2024_p2.gz"]

filenames["Movie"] = []
for i in range(1, 13):
    filenames["Movie"].append(f"../movie_2024_p{i}.gz")
    
filenames["MusicAlbum"] = []
for i in range(5):
    filenames["MusicAlbum"].append(rf"E:\schema_org_datasets\MusicAlbum\MusicAlbum_part_{i}.gz")
    
filenames["QAPage"] = []
for i in range(12):
    filenames["QAPage"].append(rf"E:\schema_org_datasets\QAPage\QAPage_part_{i}.gz")
    
filenames["Recipe"] = []
for i in range(21):
    filenames["Recipe"].append(rf"E:\schema_org_datasets\Recipe\Recipe_part_{i}.gz")
    
filenames["School"] = ["../school_2024.gz"]

filenames["ShoppingCenter"] = ["../shopping_center_2024_p1.gz", "../shopping_center_2024_p2.gz"]

# %%
processed = ["School", "ShoppingCenter", "Dataset", "Movie", "Hospital"]


for cls in schema_org_classes:
    if cls not in processed:
        print(cls)
        mean, std_dev = parse_mean_std_predicates(filenames[cls], cls, with_repeats=True)
        print()
        print(f"Vidējais predikātu skaits (ar atkārtojumiem): {mean:.2f}")
        print(f"Standartnovirze (ar atkārtojumiem): {std_dev:.2f}")
        mean, std_dev = parse_mean_std_predicates(filenames[cls], cls, with_repeats=False)
        print(f"Vidējais predikātu skaits (bez atkārtojumiem): {mean:.2f}")
        print(f"Standartnovirze (bez atkārtojumiem): {std_dev:.2f}")
        print()
        print()
# Out:
# Answer
#
# Vidējais predikātu skaits (ar atkārtojumiem): 1.73
# Standartnovirze (ar atkārtojumiem): 2.25
# Vidējais predikātu skaits (bez atkārtojumiem): 1.66
# Standartnovirze (bez atkārtojumiem): 1.35
#
#
# Book
#
# Vidējais predikātu skaits (ar atkārtojumiem): 4.91
# Standartnovirze (ar atkārtojumiem): 10.72
# Vidējais predikātu skaits (bez atkārtojumiem): 4.09
# Standartnovirze (bez atkārtojumiem): 2.69
#
#
# MusicAlbum
#
# Vidējais predikātu skaits (ar atkārtojumiem): 5.26
# Standartnovirze (ar atkārtojumiem): 8.16
# Vidējais predikātu skaits (bez atkārtojumiem): 4.07
# Standartnovirze (bez atkārtojumiem): 1.94
#
#
# QAPage
#
# Vidējais predikātu skaits (ar atkārtojumiem): 2.85
# Standartnovirze (ar atkārtojumiem): 2.28
# Vidējais predikātu skaits (bez atkārtojumiem): 2.73
# Standartnovirze (bez atkārtojumiem): 1.87
#
#
# Recipe
#
# Vidējais predikātu skaits (ar atkārtojumiem): 13.21
# Standartnovirze (ar atkārtojumiem): 8.61
# Vidējais predikātu skaits (bez atkārtojumiem): 9.31
# Standartnovirze (bez atkārtojumiem): 4.14
