# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_and_count_predicates, parse_and_count_classes

# %%
qapage_filenames = []
for i in range(12):
    qapage_filenames.append(rf"E:\schema_org_datasets\QAPage\QAPage_part_{i}.gz")

# %%
parse_and_count_classes(qapage_filenames, "QAPage", "2024")
# Out:
# <http://schema.org/QAPage>: 1922401
# <http://schema.org/Question>: 1905429
# <http://schema.org/Person>: 1708550
# <http://schema.org/Answer>: 1458481
# <http://schema.org/ListItem>: 670281
# <http://schema.org/BreadcrumbList>: 656287
# <http://schema.org/Organization>: 430531
# <https://schema.org/QAPage>: 413581
# <https://schema.org/Question>: 372034
# <https://schema.org/Answer>: 306353

# %%
parse_and_count_predicates(qapage_filenames, "QAPage", "2024")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 1986634 100.0%
# <http://schema.org/mainEntity> 1926441 96.97%
# <http://schema.org/url> 317462 15.98%
# <http://schema.org/image> 218626 11.0%
# <http://schema.org/publisher> 159258 8.02%
# <http://schema.org/datePublished> 147476 7.42%
# <http://schema.org/dateModified> 109176 5.5%
# <http://schema.org/interactionStatistic> 80561 4.06%
# <http://schema.org/author> 78769 3.96%
# <http://schema.org/dateCreated> 77160 3.88%
