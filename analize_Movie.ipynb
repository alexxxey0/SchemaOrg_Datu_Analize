# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_gz_files, top_10_predicates, parse_and_count_classes

# %%
# Iegūt četriniekus klasei Movie 2024. gada datu kopā

movie_filenames = []
for i in range(1, 13):
    movie_filenames.append(f"../movie_2024_p{i}.gz")

movie_quads = {}
movie_quads["2024"] = parse_gz_files(movie_filenames, "Movie")

# %%
top_10_predicates(movie_quads, "Movie")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 3733115 100.0%
# <http://schema.org/image> 3186455 85.36%
# <http://schema.org/url> 2450073 65.63%
# <http://schema.org/dateCreated> 1860800 49.85%
# <http://schema.org/director> 1633797 43.76%
# <http://schema.org/aggregateRating> 1294902 34.69%
# <http://schema.org/datePublished> 612552 16.41%
# <http://schema.org/actor> 566084 15.16%
# <http://schema.org/genre> 560894 15.02%
# <http://schema.org/name> 430020 11.52%

# %%
movie_filenames = []
for i in range(1, 13):
    movie_filenames.append(f"../movie_2024_p{i}.gz")
    
parse_and_count_classes(movie_filenames, "Movie", "2024")
# Out:
# <http://schema.org/Movie>: 1603892
# <http://schema.org/Person>: 1007807
# <http://schema.org/AggregateRating>: 754197
# <http://schema.org/ListItem>: 505325
# <http://schema.org/BreadcrumbList>: 480166
# <https://schema.org/Movie>: 318110
# <http://schema.org/ImageObject>: 301721
# <http://schema.org/Organization>: 294720
# <http://schema.org/VideoObject>: 276679
# <http://schema.org/WebPage>: 262758
