# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_gz_files, top_10_predicates

# %%
# Iegūt četriniekus klasei Movie 2024. gada datu kopā

movie_filenames = []
for i in range(1, 13):
    movie_filenames.append(f"../movie_2024_p{i}.gz")

movie_quads = {}
movie_quads["2024"] = parse_gz_files(movie_filenames, "Movie")

# %%
top_10_predicates(movie_quads)
# Out:
# Top 10 predikāti 2024:
# <http://schema.org/actor> 4205500 111.1%
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 3785443 100.0%
# <http://schema.org/image> 3473421 91.76%
# <http://schema.org/url> 3445792 91.03%
# <http://schema.org/dateCreated> 1914589 50.58%
# <http://schema.org/director> 1795343 47.43%
# <http://schema.org/aggregateRating> 1309844 34.6%
# <http://schema.org/genre> 1138060 30.06%
# <http://schema.org/actors> 1015777 26.83%
# <http://www.w3.org/1999/xhtml/microdata#item> 729980 19.28%
