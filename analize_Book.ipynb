# %%
# Importēt palīgfunkcijas un bibliotēkas

from helpers import parse_and_count_predicates, parse_and_count_classes, parse_and_count_domain_suffixes

# %%
book_filenames = []
for i in range(19):
    book_filenames.append(rf"E:\schema_org_datasets\Book\Book_part_{i}.gz")

# %%
parse_and_count_classes(book_filenames, "Book", "2024")
# Out:
# <http://schema.org/Book>: 3796974
# <http://schema.org/Offer>: 1748820
# <http://schema.org/Person>: 1658652
# <http://schema.org/Organization>: 1269213
# <http://schema.org/ListItem>: 927474
# <http://schema.org/BreadcrumbList>: 913293
# <http://schema.org/AggregateRating>: 787275
# <http://schema.org/WebSite>: 777169
# <http://schema.org/WebPage>: 704145
# <http://schema.org/SearchAction>: 658832

# %%
parse_and_count_predicates(book_filenames, "Book", "2024")
# Out:
# Top 10 predikāti 2024:
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 10051016 100.0%
# <http://schema.org/image> 4582533 45.59%
# <http://schema.org/author> 2581545 25.68%
# <http://schema.org/name> 2506811 24.94%
# <http://schema.org/isbn> 2484745 24.72%
# <http://schema.org/offers> 2450124 24.38%
# <http://schema.org/url> 2284848 22.73%
# <http://schema.org/bookFormat> 2051932 20.42%
# <http://schema.org/datePublished> 1985268 19.75%
# <http://schema.org/publisher> 1698348 16.9%

# %%
parse_and_count_domain_suffixes(book_filenames, "Book", "2024")
# Out:
# Top 10 sufiksi 2024:
# com 4212600 41.9%
# fr 1223824 12.17%
# org 617544 6.14%
# ca 334750 3.33%
# ro 322041 3.2%
# it 280945 2.79%
# ru 271024 2.7%
# de 267096 2.66%
# pt 223253 2.22%
# net 221414 2.2%
