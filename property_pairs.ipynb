# %%
from helpers import parse_and_count_property_pairs

schema_org_classes = [
    "Hospital",
    "School",
    "ShoppingCenter",
    "MusicAlbum",
    "QAPage",
    "Recipe",
    "Movie",
    "Answer",
    "Book",
    "Dataset",
]

filenames = {}

filenames['Answer'] = []
for i in range(118):
    filenames['Answer'].append(rf"E:\schema_org_datasets\Answer\Answer_part_{i}.gz")
    
filenames['Book'] = []
for i in range(19):
    filenames['Book'].append(rf"E:\schema_org_datasets\Book\Book_part_{i}.gz")
    
filenames['Dataset'] = []
for i in range(1, 6):
    filenames['Dataset'].append(f"../dataset_2024_p{i}.gz")
    
filenames["Hospital"] = ["../hospital_2024_p1.gz", "../hospital_2024_p2.gz"]

filenames["Movie"] = []
for i in range(1, 13):
    filenames["Movie"].append(f"../movie_2024_p{i}.gz")
    
filenames["MusicAlbum"] = []
for i in range(5):
    filenames["MusicAlbum"].append(rf"E:\schema_org_datasets\MusicAlbum\MusicAlbum_part_{i}.gz")
    
filenames["QAPage"] = []
for i in range(12):
    filenames["QAPage"].append(rf"E:\schema_org_datasets\QAPage\QAPage_part_{i}.gz")
    
filenames["Recipe"] = []
for i in range(21):
    filenames["Recipe"].append(rf"E:\schema_org_datasets\Recipe\Recipe_part_{i}.gz")
    
filenames["School"] = ["../school_2024.gz"]

filenames["ShoppingCenter"] = ["../shopping_center_2024_p1.gz", "../shopping_center_2024_p2.gz"]

# %%
processed = ["School", "Hospital", "Movie", "MusicAlbum", "QAPage", "Recipe", "ShoppingCenter"]

'''
for cls in schema_org_classes:
    if cls not in processed:
        parse_and_count_well_described_entities(cls, filenames[cls], thresholds[cls])
        print()
'''

for cls in schema_org_classes:
    if cls not in processed:
        parse_and_count_property_pairs(filenames[cls], cls, "2024")
# Out:
# Top 10 property pairs for Answer (2024):
# <http://schema.org/upvoteCount> , <http://schema.org/url> : 6321751
# <http://schema.org/author> , <http://schema.org/url> : 5817473
# <http://schema.org/author> , <http://schema.org/upvoteCount> : 5803941
# <http://schema.org/dateCreated> , <http://schema.org/upvoteCount> : 5308799
# <http://schema.org/dateCreated> , <http://schema.org/url> : 5052625
# <http://schema.org/author> , <http://schema.org/dateCreated> : 4701266
# <http://schema.org/encodingFormat> , <http://schema.org/position> : 633662
# <http://schema.org/comment> , <http://schema.org/encodingFormat> : 555380
# <http://schema.org/comment> , <http://schema.org/position> : 554775
# <http://schema.org/datePublished> , <http://schema.org/upvoteCount> : 492369
#
# Īpašība 1,Īpašība 2,Biežums
# upvoteCount,url,6321751
# author,url,5817473
# author,upvoteCount,5803941
# dateCreated,upvoteCount,5308799
# dateCreated,url,5052625
# author,dateCreated,4701266
# encodingFormat,position,633662
# comment,encodingFormat,555380
# comment,position,554775
# datePublished,upvoteCount,492369
#
#
# Top 10 property pairs for Book (2024):
# <http://schema.org/image> , <http://schema.org/offers> : 2040985
# <http://schema.org/author> , <http://schema.org/image> : 1743328
# <http://schema.org/image> , <http://schema.org/url> : 1734874
# <http://schema.org/image> , <http://schema.org/isbn> : 1687801
# <http://schema.org/datePublished> , <http://schema.org/isbn> : 1500927
# <http://schema.org/isbn> , <http://schema.org/offers> : 1477645
# <http://schema.org/image> , <http://schema.org/publisher> : 1334383
# <http://schema.org/image> , <http://schema.org/numberOfPages> : 1259035
# <http://schema.org/author> , <http://schema.org/isbn> : 1255938
# <http://schema.org/bookFormat> , <http://schema.org/isbn> : 1240274
#
# Īpašība 1,Īpašība 2,Biežums
# image,offers,2040985
# author,image,1743328
# image,url,1734874
# image,isbn,1687801
# datePublished,isbn,1500927
# isbn,offers,1477645
# image,publisher,1334383
# image,numberOfPages,1259035
# author,isbn,1255938
# bookFormat,isbn,1240274
#
#
# Top 10 property pairs for Dataset (2024):
# <http://schema.org/creator> , <http://schema.org/license> : 331659
# <http://schema.org/distribution> , <http://schema.org/license> : 270213
# <http://schema.org/creator> , <http://schema.org/url> : 255666
# <http://schema.org/distribution> , <http://schema.org/includedInDataCatalog> : 242259
# <http://schema.org/includedInDataCatalog> , <http://schema.org/license> : 241796
# <http://schema.org/license> , <http://schema.org/url> : 238403
# <http://schema.org/creator> , <http://schema.org/distribution> : 234588
# <http://schema.org/creator> , <http://schema.org/includedInDataCatalog> : 218286
# <http://schema.org/creator> , <http://schema.org/spatialCoverage> : 182093
# <http://schema.org/license> , <http://schema.org/spatialCoverage> : 176072
#
# Īpašība 1,Īpašība 2,Biežums
# creator,license,331659
# distribution,license,270213
# creator,url,255666
# distribution,includedInDataCatalog,242259
# includedInDataCatalog,license,241796
# license,url,238403
# creator,distribution,234588
# creator,includedInDataCatalog,218286
# creator,spatialCoverage,182093
# license,spatialCoverage,176072
